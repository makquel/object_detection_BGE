# %% [markdown]
# # Estudos de espaço de cor e contraste
# Durante o decorrer do projeto foram estudados os espaços de cor HSV e LAB como uma tentativa para realizar segmentação da região da pele com o intuito de falicitar ou guiar as proximas fases do processamento.

# %% [markdown]
# ### Análise do histograma

# %%
# %run -i 'histogram.py'

# %% [markdown]
# ### Equalização do histograma

# %%
# %run -i 'threshold.py'

# %% [markdown]
# ### Equalização adaptativa do histograma (Otsu)

# %%
# %run -i 'otsu_teste.py'

# %% [markdown]
# ### Segmentação usando threshold e HSV color space

# %%
# %run -i 'color_seg.py'
# Out:
# [  3  86 133]

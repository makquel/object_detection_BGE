# %% [markdown]
# # Compilando OpenCV da fonte

# %%
# !wget

# %% [markdown]
# ### Testando OpenCV lib
# Testando que a biblioteca OpenCV esteja instalada e acertado o caminho PYTHONPATH

# %%
# !echo $PYTHONPATH
# Out:
# =/home/miguel-bge/anaconda3/envs/venv/lib/python3.6/site-packages/tensorflow/models/research:/home/miguel-bge/anaconda3/envs/venv/lib/python3.6/site-packages/tensorflow/models/research:/home/miguel-bge/anaconda3/envs/venv/lib/python3.6/site-packages/tensorflow/models/research/slim:/home/miguel-bge/anaconda3/envs/venv/lib/python3.6/site-packages

# %%
import imutils
import numpy as np
import cv2 as cv
import argparse
import time
import matplotlib.pyplot as plt
print("OpenCV Version: {}".format(cv.__version__))

start = time.time()
# Load an color image in grayscale
img = cv.imread('img/peppers.png')
img = cv.cvtColor(img, cv.COLOR_BGR2GRAY)
# cv2.namedWindow('image', cv2.WINDOW_NORMAL)
# cv2.imshow('image',img)slow.flv
# cv2.waitKey(0)
# cv2.destroyAllWindows()
end = time.time()
# show timing information on YOLO
print("[INFO] OpenCV processing took {:.6f} ms".format((end - start)*1000))

plt.imshow(img, cmap = 'gray', interpolation = 'bicubic')
plt.xticks([]), plt.yticks([])  # to hide tick values on X and Y axis
plt.show()

# !python hello_world_opencv.py --image img/peppers.png
# Out:
# OpenCV Version: 3.4.6-pre
# [INFO] OpenCV processing took 12.585640 ms

# %%
# %run -i 'python resize_images.py'
# Out:
# ERROR:root:File `'python resize_images.py'` not found.
